# %% [markdown]
# <a href="https://colab.research.google.com/github/shiva676466/75DaysLeetCodeChallenge/blob/main/AdmissionPredictorProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJECT: College Admission Predictor

# %%
# importing essential libraries
